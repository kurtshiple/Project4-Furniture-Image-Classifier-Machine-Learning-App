# %%
import pandas as pd

# %%
df=pd.read_csv("B_reduced_labels.csv",encoding="utf-8")
df.head()
# Out:
#    image_id  image_id2  label_id text_id  \
# 0      1600  1600.jpeg       104   Stool
# 1      1601  1601.jpeg       104   Stool
# 2      1602  1602.jpeg       104   Stool
# 3      1603  1603.jpeg       104   Stool
# 4      1605  1605.jpeg       104   Stool
#
#                                                  url           pic_list
# 0  http://www.collection.com.tw/images/201204/133...  all_200\1600.jpeg
# 1  https://img.alicdn.com/imgextra/TB25eojeLjM8KJ...  all_200\1601.jpeg
# 2  https://img10.360buyimg.com/imgzone/jfs/t3391/...  all_200\1602.jpeg
# 3  https://img.alicdn.com/imgextra/TB1wYWPbiP85uJ...  all_200\1603.jpeg
# 4  https://img13.360buyimg.com/imgzone/jfs/t8806/...  all_200\1605.jpeg

# %%
label_df = df.groupby(['label_id', 'text_id'])
label_df.head()
# Out:
#        image_id    image_id2  label_id               text_id  \
# 0          1600    1600.jpeg       104                 Stool
# 1          1601    1601.jpeg       104                 Stool
# 2          1602    1602.jpeg       104                 Stool
# 3          1603    1603.jpeg       104                 Stool
# 4          1605    1605.jpeg       104                 Stool
# 1480       3624    3624.jpeg        67  Entertainment Center
# 1481       3625    3625.jpeg        67  Entertainment Center
# 1482       3626    3626.jpeg        67  Entertainment Center
# 1483       3628    3628.jpeg        67  Entertainment Center
# 1484       3629    3629.jpeg        67  Entertainment Center
# 2303       5764    5764.jpeg        86          Sofa/Sofabed
# 2304       5765    5765.jpeg        86          Sofa/Sofabed
# 2305       5766    5766.jpeg        86          Sofa/Sofabed
# 2306       5767    5767.jpeg        86          Sofa/Sofabed
# ...
